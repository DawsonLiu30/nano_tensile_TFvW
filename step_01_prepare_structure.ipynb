# %% [markdown]
# # Read or generate a structure

# %%
import main
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import main
#
# File D:\Code\nano_tensile_TFvW\main.py:11
#       8 from ase.io import read, write
#      10 from strain_engine import apply_strain
# ---> 11 from dft_engine import relax_atoms
#      14 # ---------- Grid Conversion: ecut(eV) -> spacing(Angstrom) ----------
#      15 # Nyquist: Gmax ~ pi / h  (h in bohr)
#      16 # Ecut(Ha) = 0.5 * Gmax^2 = pi^2 / (2 h^2)
#      17 # => h(bohr) = pi / sqrt(2*Ecut(Ha))
#      18 # Ecut(Ha) = Ecut(eV) / Ha_to_eV
#      19 HA_TO_EV = 27.211386245988
#
# File D:\Code\nano_tensile_TFvW\dft_engine.py:10
#       7 from ase.constraints import FixAtoms
#       8 from ase.optimize import BFGS
# ---> 10 from dftpy.config import DefaultOption, OptionFormat
#      11 from dftpy.api.api4ase import DFTpyCalculator
# ...
