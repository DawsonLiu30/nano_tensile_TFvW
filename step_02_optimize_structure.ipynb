# %% [markdown]
# # Show how to optimize the structure loaded in step 01
# # Step 02 — Prepare grip regions
# This step identifies bottom and top grip atoms based on z-position.
# The structure itself is NOT modified.

# %%
END_FRAC = 0.10
MIN_THICKNESS = 2.0
MAX_THICKNESS = 8.0
MIN_LAYERS = 2
EPS = 1e-3

# %%
# !python auto_prep.py structure_0.xyz \
    --end-frac {END_FRAC} \
    --min-thickness {MIN_THICKNESS} \
    --max-thickness {MAX_THICKNESS} \
    --min-layers {MIN_LAYERS} \
    --eps {EPS}
# Out:
# --- Processing structure_0.xyz ---
# [AutoPrep] Atomic Z-range: 38.475000 A
#            z_min=0.000000, z_max=38.475000
#            End-fraction (per side): 0.1000  -> target_thickness_raw=3.847500 A
#            thickness clip: [2.000, 8.000] -> target_thickness=3.847500 A
#            eps=0.001, distinct_z_levels=20
#            min_layers=2, max_layers=unlimited
# [AutoPrep] Bottom: layers=2, atoms=9, z=[0.000000, 2.025000], thickness~=2.025000 A
# [AutoPrep] Top:    layers=2, atoms=9, z=[36.450000, 38.475000], thickness~=2.025000 A
# [AutoPrep] Gap (top_min - bottom_max): 34.425000 A
# [AutoPrep] Total grip fraction: 0.200000
# [Success] Saved grips:
#           Bottom atoms: 9 -> bottom_idx.npy
#           Top atoms:    9 -> top_idx.npy

# %%
import numpy as np

bottom = np.load("bottom_idx.npy")
top = np.load("top_idx.npy")

print("Bottom atoms:", len(bottom))
print("Top atoms   :", len(top))
# Out:
# Bottom atoms: 9
# Top atoms   : 9
