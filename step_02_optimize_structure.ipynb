# %% [markdown]
# # Show how to optimize the structure loaded in step 01
# # Step 02 — Prepare grip regions

# %%
from pathlib import Path
import json
import numpy as np
from ase.io import read

import auto_prep

ROOT = Path.cwd()
WORKDIR = ROOT / "cases" / "case_center"

init_vasp = WORKDIR / "init.vasp"
assert init_vasp.exists(), f"Missing {init_vasp}"

atoms = read(str(init_vasp))
print("N_atoms =", len(atoms))
print("WORKDIR =", WORKDIR)
# Out:
# N_atoms = 359
# WORKDIR = /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center

# %% [markdown]
# ## define the calculation

# %%
end_frac = 0.08
eps = 1e-3
min_layers = 2
max_layers = None

bottom_idx, top_idx = auto_prep.get_grip_indices(
    atoms,
    end_frac=end_frac,
    eps=eps,
    min_layers=min_layers,
    max_layers=max_layers,
    debug=True,
)

print("Bottom atoms =", len(bottom_idx))
print("Top atoms    =", len(top_idx))
# Out:
# [AutoPrep] Atomic Z-range: 39.750566 A
#            z_min=0.000000, z_max=39.750566
#            End-fraction (per side): 0.0800  -> target_thickness_raw=3.180045 A
#            thickness clip: [2.000, 8.000] -> target_thickness=3.180045 A
#            eps=0.001, distinct_z_levels=18
#            min_layers=2, max_layers=unlimited
# [AutoPrep] Bottom: layers=2, atoms=41, z=[0.000000, 2.338269], thickness~=2.338000 A
# [AutoPrep] Top:    layers=2, atoms=38, z=[37.412297, 39.750566], thickness~=2.339000 A
# [AutoPrep] Gap (top_min - bottom_max): 35.074029 A
# [AutoPrep] Total grip fraction: 0.220056
# Bottom atoms = 41
# Top atoms    = 38

# %% [markdown]
# ## configure the DFTpy run

# %%
np.save(WORKDIR / "bottom_idx.npy", bottom_idx)
np.save(WORKDIR / "top_idx.npy", top_idx)

assert len(set(bottom_idx) & set(top_idx)) == 0
assert len(bottom_idx) > 0 and len(top_idx) > 0

grip_meta = {
    "end_frac": float(end_frac),
    "eps": float(eps),
    "min_layers": int(min_layers),
    "max_layers": None if max_layers is None else int(max_layers),
    "n_bottom": int(len(bottom_idx)),
    "n_top": int(len(top_idx)),
}
(WORKDIR / "grip_meta.json").write_text(json.dumps(grip_meta, indent=2))

print("Saved:", WORKDIR / "bottom_idx.npy")
print("Saved:", WORKDIR / "top_idx.npy")
print("Saved:", WORKDIR / "grip_meta.json")
print("Grip regions OK")
# Out:
# Saved: /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/bottom_idx.npy
# Saved: /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/top_idx.npy
# Saved: /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/grip_meta.json
# Grip regions OK

# %%
from ase.io import read, write
import main
import dft_engine

pp = ROOT / "al.gga.psp"
assert pp.exists(), f"Missing {pp}"

ecut_ev = 500.0
spacing = float(main.ecut_to_spacing_angstrom(ecut_ev))

bottom_idx = np.load(WORKDIR / "bottom_idx.npy")
top_idx = np.load(WORKDIR / "top_idx.npy")
fixed_idx = np.unique(np.r_[bottom_idx, top_idx]).astype(int)

atoms0 = read(str(WORKDIR / "init.vasp"))

atoms0_rlx, E0, S0 = dft_engine.relax_atoms(
    atoms0,
    pp_file=pp,
    spacing=spacing,
    fixed_idx=fixed_idx,
    fmax=0.05,
    steps=200,
    logfile=str(WORKDIR / "cycle_000_relax.log"),
    trajfile=str(WORKDIR / "cycle_000_relax.traj"),
    dftpy_outfile=str(WORKDIR / "cycle_000_dftpy.out"),
    debug_fixed=True,
)

ref_xyz = WORKDIR / "cycle_000_relaxed.xyz"
write(str(ref_xyz), atoms0_rlx)

ref = {"E_ref_eV": float(E0), "ecut_ev": float(ecut_ev), "spacing_A": float(spacing)}
ref_json = WORKDIR / "ref_energy.json"
ref_json.write_text(json.dumps(ref, indent=2))

print("E_ref_eV =", f"{E0:.12f}")
print("Saved:", ref_xyz)
print("Saved:", ref_json)
# Out:
# Saved:
#  - /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/bottom_idx.npy
#  - /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/top_idx.npy

# %%
from pathlib import Path
import json
import numpy as np
from ase.io import read, write
import main
import dft_engine

ROOT = Path.cwd()
WORKDIR = ROOT / "cases" / "case_center"
pp = ROOT / "al.gga.psp"

assert (WORKDIR / "init.vasp").exists()
assert (WORKDIR / "bottom_idx.npy").exists()
assert (WORKDIR / "top_idx.npy").exists()
assert pp.exists()

ecut_ev = 500.0
spacing = float(main.ecut_to_spacing_angstrom(ecut_ev))

bottom_idx = np.load(WORKDIR / "bottom_idx.npy")
top_idx = np.load(WORKDIR / "top_idx.npy")
fixed_idx = np.unique(np.r_[bottom_idx, top_idx]).astype(int)

atoms0 = read(str(WORKDIR / "init.vasp"))

atoms0_rlx, E0, S0 = dft_engine.relax_atoms(
    atoms0,
    pp_file=pp,
    spacing=spacing,
    fixed_idx=fixed_idx,
    fmax=0.05,
    steps=200,
    logfile=str(WORKDIR / "cycle_000_relax.log"),
    trajfile=str(WORKDIR / "cycle_000_relax.traj"),
    dftpy_outfile=str(WORKDIR / "cycle_000_dftpy.out"),
    debug_fixed=True,
)

ref_xyz = WORKDIR / "cycle_000_relaxed.xyz"
write(str(ref_xyz), atoms0_rlx)

ref_json = WORKDIR / "ref_energy.json"
ref_json.write_text(json.dumps(
    {"E_ref_eV": float(E0), "ecut_ev": float(ecut_ev), "spacing_A": float(spacing)},
    indent=2
))

print("Saved:", ref_xyz, "exists:", ref_xyz.exists())
print("Saved:", ref_json, "exists:", ref_json.exists())
print("E_ref_eV =", f"{E0:.12f}")
# Out:
# [relax_atoms] before run fixed_z(min/max)=0.000000/39.750566
# The final grid size is  [ 78  78 154]
# setting key: Al -> /Users/dawson666/Desktop/nano_tensile_TFvW/al.gga.psp
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       2.792476049202E+03      2.792476E+03    2.840297E+04    1       1       3.103790E-01
# !WARN : pAp small than zero :iter =  1 -3993145.5123826605
# 1       -4.954174877307E+02     -3.287894E+03   1.043612E+03    2       2       7.113459E-01
# 2       -7.047429774287E+02     -2.093255E+02   1.807121E+02    3       1       1.098303E+00
# !WARN : pAp small than zero :iter =  7 -28075.660393028054
# 3       -7.304799475177E+02     -2.573697E+01   5.121225E+01    8       2       2.039878E+00
# 4       -7.493893270876E+02     -1.890938E+01   5.140470E+00    12      2       3.291180E+00
# 5       -7.502926091373E+02     -9.032820E-01   6.743429E-01    10      2       4.367210E+00
# 6       -7.504646827237E+02     -1.720736E-01   2.323802E-01    15      2       5.887418E+00
# 7       -7.505182183351E+02     -5.353561E-02   5.899628E-02    10      2       6.939775E+00
# 8       -7.505461568879E+02     -2.793855E-02   3.074346E-02    14      1       8.243391E+00
# 9       -7.505552604023E+02     -9.103514E-03   7.916335E-03    12      2       9.534008E+00
# 10      -7.505606531185E+02     -5.392716E-03   5.530925E-03    14      1       1.084781E+01
# 11      -7.505628415220E+02     -2.188404E-03   1.324065E-03    14      2       1.230651E+01
# 12      -7.505634945223E+02     -6.530003E-04   6.992247E-04    13      2       1.363507E+01
# 13      -7.505638180009E+02     -3.234786E-04   2.454024E-04    14      2       1.505430E+01
# 14      -7.505639209056E+02     -1.029047E-04   1.112909E-04    15      2       1.654757E+01
# 15      -7.505639748054E+02     -5.389979E-05   4.430352E-05    16      1       1.800475E+01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.024401136108297326
# Chemical potential (eV)  : -0.6639887340760048
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.367636610855970E+04
#         II energy (eV):  7.591077843689742E+04
#    KEDF-NL energy (eV): -7.805092116746075E+02
#    KEDF-TF energy (eV):  7.094590161725988E+03
#    KEDF-VW energy (eV):  1.268281358290918E+03
#     PSEUDO energy (eV): -1.901054721847824E+05
#         XC energy (eV): -7.487920723429977E+03
#      TOTAL energy (eV): -2.042388605441293E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            278.646677591227672
#   kedfs energy (eV)              :           7582.362308342298093
#   total energy (a.u.)            :           -750.563974805390444
#   total energy (eV)              :         -20423.886054412931117
#   total energy (eV/atom)         :            -56.891047505328501
# Calculate Force...
#               Max force (a.u.) : 0.01866
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00521
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00044     -0.00001     -0.00000
#                     -0.00001      0.00028     -0.00000
#                     -0.00000     -0.00000     -0.02603
#         II stress (a.u.):
#                      0.00188     -0.00001     -0.00000
#                     -0.00001      0.00263      0.00001
#                     -0.00000      0.00001     -0.02573
#    KEDF-NL stress (a.u.):
#                      0.00016      0.00000     -0.00000
#                      0.00000      0.00017      0.00000
#                     -0.00000      0.00000      0.00010
#    KEDF-TF stress (a.u.):
#                     -0.00132      0.00000      0.00000
#                      0.00000     -0.00132      0.00000
#                      0.00000      0.00000     -0.00132
#    KEDF-VW stress (a.u.):
#                     -0.00026     -0.00000      0.00000
#                     -0.00000     -0.00027     -0.00000
#                      0.00000     -0.00000     -0.00018
#     PSEUDO stress (a.u.):
#                     -0.00069      0.00001      0.00000
#                      0.00001     -0.00216     -0.00001
#                      0.00000     -0.00001      0.05254
#         XC stress (a.u.):
#                      0.00063      0.00000      0.00000
#                      0.00000      0.00063      0.00000
#                      0.00000      0.00000      0.00063
#      TOTAL stress (a.u.):
#                     -0.00004      0.00000     -0.00000
#                      0.00000     -0.00004     -0.00000
#                     -0.00000     -0.00000      0.00001
#      TOTAL stress (GPa):
#                     -1.04758      0.00057     -0.00118
#                      0.00057     -1.12856     -0.11617
#                     -0.00118     -0.11617      0.25439
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.505969025492E+02     -7.505969E+02   5.165641E-02    1       1       2.369821E-01
# 1       -7.506173948693E+02     -2.049232E-02   1.426160E-02    10      2       1.249237E+00
# 2       -7.506196144419E+02     -2.219573E-03   1.755194E-03    11      2       2.360438E+00
# 3       -7.506200131011E+02     -3.986592E-04   4.681330E-04    11      2       3.466553E+00
# 4       -7.506200862717E+02     -7.317067E-05   5.485100E-05    7       2       4.238534E+00
# 5       -7.506200981262E+02     -1.185445E-05   1.585891E-05    12      1       5.342210E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02381721501393447
# Chemical potential (eV)  : -0.6480994317695261
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.379999927387726E+04
#         II energy (eV):  7.601752635310823E+04
#    KEDF-NL energy (eV): -7.832395868068571E+02
#    KEDF-TF energy (eV):  7.101510733374871E+03
#    KEDF-VW energy (eV):  1.268775225107412E+03
#     PSEUDO energy (eV): -1.903387098107770E+05
#         XC energy (eV): -7.491275435643985E+03
#      TOTAL energy (eV): -2.042541324776013E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            278.818813745149953
#   kedfs energy (eV)              :           7587.046371675426599
#   total energy (a.u.)            :           -750.620098126188168
#   total energy (eV)              :         -20425.413247760126978
#   total energy (eV/atom)         :            -56.895301525794224
# Calculate Force...
#               Max force (a.u.) : 0.01935
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00539
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00044     -0.00001     -0.00000
#                     -0.00001      0.00028     -0.00000
#                     -0.00000     -0.00000     -0.02607
#         II stress (a.u.):
#                      0.00189     -0.00001     -0.00000
#                     -0.00001      0.00263      0.00001
#                     -0.00000      0.00001     -0.02576
#    KEDF-NL stress (a.u.):
#                      0.00016      0.00000     -0.00000
#                      0.00000      0.00017      0.00000
#                     -0.00000      0.00000      0.00010
#    KEDF-TF stress (a.u.):
#                     -0.00132      0.00000      0.00000
#                      0.00000     -0.00132      0.00000
#                      0.00000      0.00000     -0.00132
#    KEDF-VW stress (a.u.):
#                     -0.00026     -0.00000      0.00000
#                     -0.00000     -0.00027     -0.00000
#                      0.00000     -0.00000     -0.00018
#     PSEUDO stress (a.u.):
#                     -0.00070      0.00001      0.00000
#                      0.00001     -0.00216     -0.00001
#                      0.00000     -0.00001      0.05261
#         XC stress (a.u.):
#                      0.00063      0.00000      0.00000
#                      0.00000      0.00063      0.00000
#                      0.00000      0.00000      0.00063
#      TOTAL stress (a.u.):
#                     -0.00004      0.00000     -0.00000
#                      0.00000     -0.00004     -0.00000
#                     -0.00000     -0.00000      0.00001
#      TOTAL stress (GPa):
#                     -1.07086      0.00051     -0.00124
#                      0.00051     -1.15012     -0.11599
#                     -0.00124     -0.11599      0.25634
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.475186745614E+02     -7.475187E+02   9.264347E+00    1       1       2.373431E-01
# 1       -7.511035252197E+02     -3.584851E+00   2.615347E+00    9       1       1.090448E+00
# 2       -7.514483409250E+02     -3.448157E-01   4.775195E-01    12      2       2.276654E+00
# 3       -7.514892867139E+02     -4.094579E-02   3.015618E-02    5       1       2.782407E+00
# 4       -7.515006027124E+02     -1.131600E-02   5.177664E-03    10      1       3.720358E+00
# 5       -7.515015453916E+02     -9.426792E-04   7.502991E-04    11      2       4.793243E+00
# 6       -7.515018015710E+02     -2.561794E-04   3.111333E-04    13      2       6.058446E+00
# 7       -7.515018622496E+02     -6.067861E-05   5.741410E-05    12      2       7.275765E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.022957429463834975
# Chemical potential (eV)  : -0.6247034752675958
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.535689093946286E+04
#         II energy (eV):  7.753419130034321E+04
#    KEDF-NL energy (eV): -8.565826375758645E+02
#    KEDF-TF energy (eV):  7.211095394387688E+03
#    KEDF-VW energy (eV):  1.298436406418086E+03
#     PSEUDO energy (eV): -1.934532478826361E+05
#         XC energy (eV): -7.540190792104664E+03
#      TOTAL energy (eV): -2.044940727170476E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            281.240696683985504
#   kedfs energy (eV)              :           7652.949163229910482
#   total energy (a.u.)            :           -751.501862249601345
#   total energy (eV)              :         -20449.407271704760205
#   total energy (eV/atom)         :            -56.962137247088471
# Calculate Force...
#               Max force (a.u.) : 0.02787
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00719
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00041     -0.00001     -0.00000
#                     -0.00001      0.00027     -0.00000
#                     -0.00000     -0.00000     -0.02651
#         II stress (a.u.):
#                      0.00194     -0.00001     -0.00000
#                     -0.00001      0.00263      0.00000
#                     -0.00000      0.00000     -0.02625
#    KEDF-NL stress (a.u.):
#                      0.00018      0.00000      0.00000
#                      0.00000      0.00019      0.00000
#                      0.00000      0.00000      0.00011
#    KEDF-TF stress (a.u.):
#                     -0.00134      0.00000      0.00000
#                      0.00000     -0.00134      0.00000
#                      0.00000      0.00000     -0.00134
#    KEDF-VW stress (a.u.):
#                     -0.00028     -0.00000     -0.00000
#                     -0.00000     -0.00028     -0.00000
#                     -0.00000     -0.00000     -0.00018
#     PSEUDO stress (a.u.):
#                     -0.00078      0.00001      0.00000
#                      0.00001     -0.00216     -0.00001
#                      0.00000     -0.00001      0.05354
#         XC stress (a.u.):
#                      0.00064      0.00000      0.00000
#                      0.00000      0.00064      0.00000
#                      0.00000      0.00000      0.00064
#      TOTAL stress (a.u.):
#                     -0.00005      0.00000     -0.00000
#                      0.00000     -0.00005     -0.00000
#                     -0.00000     -0.00000      0.00000
#      TOTAL stress (GPa):
#                     -1.51822      0.00078     -0.00273
#                      0.00078     -1.55352     -0.11778
#                     -0.00273     -0.11778      0.07031
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.484652070775E+02     -7.484652E+02   1.003915E+01    1       1       2.453282E-01
# 1       -7.522080605095E+02     -3.742853E+00   2.350118E+00    8       1       9.965241E-01
# 2       -7.525208034513E+02     -3.127429E-01   3.342655E-01    9       2       1.914350E+00
# 3       -7.525612790685E+02     -4.047562E-02   4.482907E-02    9       2       2.826966E+00
# 4       -7.525680576960E+02     -6.778627E-03   8.033202E-03    8       2       3.661488E+00
# 5       -7.525703351388E+02     -2.277443E-03   1.577621E-03    12      1       4.727542E+00
# 6       -7.525707447249E+02     -4.095862E-04   3.314825E-04    15      2       6.133799E+00
# 7       -7.525708235934E+02     -7.886854E-05   7.396264E-05    11      2       7.220028E+00
# 8       -7.525708493679E+02     -2.577448E-05   2.908743E-05    15      2       8.667878E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02204795370194102
# Chemical potential (eV)  : -0.5999553792308939
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.696632333105271E+04
#         II energy (eV):  7.907334143165551E+04
#    KEDF-NL energy (eV): -1.002259267876116E+03
#    KEDF-TF energy (eV):  7.365006314762532E+03
#    KEDF-VW energy (eV):  1.378921002312901E+03
#     PSEUDO energy (eV): -1.966553345766641E+05
#         XC energy (eV): -7.604494128080060E+03
#      TOTAL energy (eV): -2.047849589283665E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            284.501055634094143
#   kedfs energy (eV)              :           7741.668049199316556
#   total energy (a.u.)            :           -752.570849367928986
#   total energy (eV)              :         -20478.495892836650455
#   total energy (eV/atom)         :            -57.043164046898745
# Calculate Force...
#               Max force (a.u.) : 0.03339
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00859
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00040     -0.00001     -0.00000
#                     -0.00001      0.00025      0.00000
#                     -0.00000      0.00000     -0.02696
#         II stress (a.u.):
#                      0.00199     -0.00001     -0.00000
#                     -0.00001      0.00263     -0.00000
#                     -0.00000     -0.00000     -0.02672
#    KEDF-NL stress (a.u.):
#                      0.00022      0.00000      0.00000
#                      0.00000      0.00022      0.00000
#                      0.00000      0.00000      0.00012
#    KEDF-TF stress (a.u.):
#                     -0.00137      0.00000      0.00000
#                      0.00000     -0.00137      0.00000
#                      0.00000      0.00000     -0.00137
#    KEDF-VW stress (a.u.):
#                     -0.00030     -0.00000     -0.00000
#                     -0.00000     -0.00029     -0.00000
#                     -0.00000     -0.00000     -0.00018
#     PSEUDO stress (a.u.):
#                     -0.00087      0.00001      0.00000
#                      0.00001     -0.00216     -0.00000
#                      0.00000     -0.00000      0.05446
#         XC stress (a.u.):
#                      0.00064      0.00000      0.00000
#                      0.00000      0.00064      0.00000
#                      0.00000      0.00000      0.00064
#      TOTAL stress (a.u.):
#                     -0.00008      0.00000     -0.00000
#                      0.00000     -0.00008     -0.00000
#                     -0.00000     -0.00000     -0.00002
#      TOTAL stress (GPa):
#                     -2.34962      0.00277     -0.00431
#                      0.00277     -2.40271     -0.13126
#                     -0.00431     -0.13126     -0.53257
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.491647756509E+02     -7.491648E+02   1.180444E+01    1       1       2.456679E-01
# 1       -7.533260464665E+02     -4.161271E+00   2.626670E+00    8       1       1.004902E+00
# 2       -7.536410859067E+02     -3.150394E-01   4.215205E-01    7       2       1.762922E+00
# 3       -7.536870679627E+02     -4.598206E-02   6.474487E-02    7       2       2.541316E+00
# 4       -7.537016958478E+02     -1.462789E-02   1.043641E-02    12      2       3.719171E+00
# 5       -7.537043067784E+02     -2.610931E-03   2.095661E-03    9       2       4.638735E+00
# 6       -7.537050207750E+02     -7.139966E-04   5.254280E-04    13      2       5.884813E+00
# 7       -7.537051548030E+02     -1.340280E-04   8.637115E-05    9       2       6.807611E+00
# 8       -7.537052007353E+02     -4.593232E-05   4.824575E-05    16      1       8.240752E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.021998082972247535
# Chemical potential (eV)  : -0.5985983275538876
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.862107477480947E+04
#         II energy (eV):  8.065594835174552E+04
#    KEDF-NL energy (eV): -1.222694917263640E+03
#    KEDF-TF energy (eV):  7.562460041212109E+03
#    KEDF-VW energy (eV):  1.512185495729162E+03
#     PSEUDO energy (eV): -1.999553614657184E+05
#         XC energy (eV): -7.682975446295847E+03
#      TOTAL energy (eV): -2.050936316578159E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            288.553865379968840
#   kedfs energy (eV)              :           7851.950619677631039
#   total energy (a.u.)            :           -753.705200735304970
#   total energy (eV)              :         -20509.363165781585849
#   total energy (eV/atom)         :            -57.129145308583801
# Calculate Force...
#               Max force (a.u.) : 0.03927
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00938
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00039     -0.00001     -0.00000
#                     -0.00001      0.00023      0.00000
#                     -0.00000      0.00000     -0.02741
#         II stress (a.u.):
#                      0.00203     -0.00001     -0.00000
#                     -0.00001      0.00263     -0.00001
#                     -0.00000     -0.00001     -0.02720
#    KEDF-NL stress (a.u.):
#                      0.00027      0.00000     -0.00000
#                      0.00000      0.00026      0.00000
#                     -0.00000      0.00000      0.00016
#    KEDF-TF stress (a.u.):
#                     -0.00141      0.00000      0.00000
#                      0.00000     -0.00141      0.00000
#                      0.00000      0.00000     -0.00141
#    KEDF-VW stress (a.u.):
#                     -0.00033     -0.00000      0.00000
#                     -0.00000     -0.00032     -0.00000
#                      0.00000     -0.00000     -0.00020
#     PSEUDO stress (a.u.):
#                     -0.00095      0.00001      0.00000
#                      0.00001     -0.00216     -0.00000
#                      0.00000     -0.00000      0.05536
#         XC stress (a.u.):
#                      0.00065      0.00000      0.00000
#                      0.00000      0.00065      0.00000
#                      0.00000      0.00000      0.00065
#      TOTAL stress (a.u.):
#                     -0.00012      0.00000      0.00000
#                      0.00000     -0.00013     -0.00001
#                      0.00000     -0.00001     -0.00006
#      TOTAL stress (GPa):
#                     -3.62258      0.00599      0.00003
#                      0.00599     -3.70340     -0.17028
#                      0.00003     -0.17028     -1.68596
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.495490575999E+02     -7.495491E+02   1.412536E+01    1       1       2.380538E-01
# 1       -7.542422603065E+02     -4.693203E+00   2.975742E+00    8       1       1.005190E+00
# 2       -7.545822684378E+02     -3.400081E-01   4.611086E-01    7       2       1.771016E+00
# 3       -7.546308611404E+02     -4.859270E-02   7.155940E-02    6       2       2.442759E+00
# 4       -7.546477676786E+02     -1.690654E-02   1.380488E-02    12      1       3.507553E+00
# 5       -7.546508269838E+02     -3.059305E-03   2.019327E-03    9       2       4.436282E+00
# 6       -7.546515634942E+02     -7.365104E-04   4.724836E-04    13      2       5.678003E+00
# 7       -7.546516695692E+02     -1.060750E-04   6.593883E-05    12      2       6.834354E+00
# 8       -7.546516945846E+02     -2.501546E-05   3.668556E-05    14      1       8.074972E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02236312055474622
# Chemical potential (eV)  : -0.6085315061246611
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.003033682030112E+05
#         II energy (eV):  8.225765138912939E+04
#    KEDF-NL energy (eV): -1.517893507341616E+03
#    KEDF-TF energy (eV):  7.801960812231541E+03
#    KEDF-VW energy (eV):  1.696366786738282E+03
#     PSEUDO energy (eV): -2.033027611523561E+05
#         XC energy (eV): -7.773811106698143E+03
#      TOTAL energy (eV): -2.053511857528551E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            293.275545923382595
#   kedfs energy (eV)              :           7980.434091628207170
#   total energy (a.u.)            :           -754.651694584639245
#   total energy (eV)              :         -20535.118575285508996
#   total energy (eV/atom)         :            -57.200887396338466
# Calculate Force...
#               Max force (a.u.) : 0.04851
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.01077
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00039     -0.00000     -0.00000
#                     -0.00000      0.00020      0.00001
#                     -0.00000      0.00001     -0.02786
#         II stress (a.u.):
#                      0.00205     -0.00001     -0.00000
#                     -0.00001      0.00261     -0.00002
#                     -0.00000     -0.00002     -0.02766
#    KEDF-NL stress (a.u.):
#                      0.00034      0.00000     -0.00000
#                      0.00000      0.00031      0.00000
#                     -0.00000      0.00000      0.00020
#    KEDF-TF stress (a.u.):
#                     -0.00145      0.00000      0.00000
#                      0.00000     -0.00145      0.00000
#                      0.00000      0.00000     -0.00145
#    KEDF-VW stress (a.u.):
#                     -0.00037      0.00000      0.00000
#                      0.00000     -0.00035     -0.00000
#                      0.00000     -0.00000     -0.00023
#     PSEUDO stress (a.u.):
#                     -0.00102      0.00001      0.00000
#                      0.00001     -0.00216      0.00000
#                      0.00000      0.00000      0.05621
#         XC stress (a.u.):
#                      0.00066      0.00000      0.00000
#                      0.00000      0.00066      0.00000
#                      0.00000      0.00000      0.00066
#      TOTAL stress (a.u.):
#                     -0.00018      0.00000      0.00000
#                      0.00000     -0.00019     -0.00001
#                      0.00000     -0.00001     -0.00012
#      TOTAL stress (GPa):
#                     -5.38912      0.01379      0.02276
#                      0.01379     -5.48908     -0.27749
#                      0.02276     -0.27749     -3.53777
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.495815141118E+02     -7.495815E+02   1.612963E+01    1       1       2.373581E-01
# 1       -7.546877266680E+02     -5.106213E+00   2.902651E+00    6       1       8.471200E-01
# 2       -7.550448636483E+02     -3.571370E-01   4.047334E-01    7       2       1.594574E+00
# 3       -7.551223184781E+02     -7.745483E-02   5.308757E-02    9       2       2.492734E+00
# 4       -7.551391807332E+02     -1.686226E-02   1.308096E-02    12      2       3.655660E+00
# 5       -7.551420103718E+02     -2.829639E-03   1.843344E-03    9       2       4.557838E+00
# 6       -7.551426951954E+02     -6.848236E-04   5.826485E-04    13      2       5.789069E+00
# 7       -7.551428228663E+02     -1.276709E-04   7.792612E-05    9       2       6.696381E+00
# 8       -7.551428608474E+02     -3.798110E-05   3.695845E-05    14      2       8.007194E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.023126929286794346
# Chemical potential (eV)  : -0.6293158003812052
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.018475596696054E+05
#         II energy (eV):  8.371801047304952E+04
#    KEDF-NL energy (eV): -1.881869915149332E+03
#    KEDF-TF energy (eV):  8.072374611126048E+03
#    KEDF-VW energy (eV):  1.922839976829187E+03
#     PSEUDO energy (eV): -2.063563084496436E+05
#         XC energy (eV): -7.871090255880542E+03
#      TOTAL energy (eV): -2.054848389006327E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            298.159919731415641
#   kedfs energy (eV)              :           8113.344672805902519
#   total energy (a.u.)            :           -755.142860847386601
#   total energy (eV)              :         -20548.483890063274885
#   total energy (eV/atom)         :            -57.238116685413019
# Calculate Force...
#               Max force (a.u.) : 0.10755
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.01344
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00040     -0.00000     -0.00000
#                     -0.00000      0.00017      0.00001
#                     -0.00000      0.00001     -0.02824
#         II stress (a.u.):
#                      0.00206     -0.00001     -0.00001
#                     -0.00001      0.00258     -0.00004
#                     -0.00001     -0.00004     -0.02804
#    KEDF-NL stress (a.u.):
#                      0.00041     -0.00000     -0.00000
#                     -0.00000      0.00037      0.00000
#                     -0.00000      0.00000      0.00027
#    KEDF-TF stress (a.u.):
#                     -0.00150      0.00000      0.00000
#                      0.00000     -0.00150      0.00000
#                      0.00000      0.00000     -0.00150
#    KEDF-VW stress (a.u.):
#                     -0.00042      0.00000      0.00000
#                      0.00000     -0.00039     -0.00000
#                      0.00000     -0.00000     -0.00027
#     PSEUDO stress (a.u.):
#                     -0.00108      0.00001      0.00001
#                      0.00001     -0.00215      0.00001
#                      0.00001      0.00001      0.05691
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00026      0.00000      0.00000
#                      0.00000     -0.00026     -0.00002
#                      0.00000     -0.00002     -0.00021
#      TOTAL stress (GPa):
#                     -7.74287      0.02471      0.04676
#                      0.02471     -7.66244     -0.50836
#                      0.04676     -0.50836     -6.13555
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.551380309684E+02     -7.551380E+02   1.130920E+00    1       1       2.426653E-01
# 1       -7.555755718081E+02     -4.375408E-01   1.293857E-01    6       1       8.380122E-01
# 2       -7.555975572356E+02     -2.198543E-02   1.557138E-02    9       1       1.661949E+00
# 3       -7.556006732617E+02     -3.116026E-03   2.874236E-03    12      2       2.817151E+00
# 4       -7.556012395818E+02     -5.663202E-04   4.189388E-04    11      2       3.895938E+00
# 5       -7.556013204540E+02     -8.087211E-05   8.768450E-05    11      2       4.961804E+00
# 6       -7.556013370214E+02     -1.656748E-05   1.438509E-05    11      2       6.035872E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.023010007343042812
# Chemical potential (eV)  : -0.6261341922350628
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.018074641217030E+05
#         II energy (eV):  8.363638374665564E+04
#    KEDF-NL energy (eV): -1.949216042623636E+03
#    KEDF-TF energy (eV):  8.106630009044959E+03
#    KEDF-VW energy (eV):  1.962584608848143E+03
#     PSEUDO energy (eV): -2.062423728929789E+05
#         XC energy (eV): -7.882433212867453E+03
#      TOTAL energy (eV): -2.056095966221823E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            298.404446138766048
#   kedfs energy (eV)              :           8119.998575269466528
#   total energy (a.u.)            :           -755.601337021433210
#   total energy (eV)              :         -20560.959662218232552
#   total energy (eV/atom)         :            -57.272868139883656
# Calculate Force...
#               Max force (a.u.) : 0.08022
#               Min force (a.u.) : 0.00001
#               Ave force (a.u.) : 0.01220
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00040     -0.00000     -0.00000
#                     -0.00000      0.00017      0.00001
#                     -0.00000      0.00001     -0.02823
#         II stress (a.u.):
#                      0.00207     -0.00001     -0.00001
#                     -0.00001      0.00258     -0.00004
#                     -0.00001     -0.00004     -0.02802
#    KEDF-NL stress (a.u.):
#                      0.00043     -0.00000     -0.00000
#                     -0.00000      0.00038      0.00000
#                     -0.00000      0.00000      0.00028
#    KEDF-TF stress (a.u.):
#                     -0.00151      0.00000      0.00000
#                      0.00000     -0.00151      0.00000
#                      0.00000      0.00000     -0.00151
#    KEDF-VW stress (a.u.):
#                     -0.00042      0.00000      0.00000
#                      0.00000     -0.00040     -0.00000
#                      0.00000     -0.00000     -0.00028
#     PSEUDO stress (a.u.):
#                     -0.00109      0.00001      0.00001
#                      0.00001     -0.00215      0.00002
#                      0.00001      0.00002      0.05687
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00027      0.00000      0.00000
#                      0.00000     -0.00027     -0.00002
#                      0.00000     -0.00002     -0.00022
#      TOTAL stress (GPa):
#                     -7.88290      0.01584      0.02700
#                      0.01584     -7.84064     -0.49415
#                      0.02700     -0.49415     -6.42513
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.527013023489E+02     -7.527013E+02   9.342274E+00    1       1       2.305858E-01
# 1       -7.563740050793E+02     -3.672703E+00   1.249401E+00    6       1       8.069830E-01
# 2       -7.565486102553E+02     -1.746052E-01   1.600812E-01    8       1       1.532758E+00
# 3       -7.565797661628E+02     -3.115591E-02   2.611125E-02    12      2       2.668196E+00
# 4       -7.565856230730E+02     -5.856910E-03   4.813374E-03    11      2       3.733655E+00
# 5       -7.565864936357E+02     -8.705627E-04   9.075576E-04    11      2       4.813475E+00
# 6       -7.565866683886E+02     -1.747529E-04   1.849966E-04    11      2       5.888972E+00
# 7       -7.565867039441E+02     -3.555549E-05   3.902132E-05    11      2       6.974445E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.023799227802275086
# Chemical potential (eV)  : -0.6476099748095606
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.016547335615987E+05
#         II energy (eV):  8.339274131169997E+04
#    KEDF-NL energy (eV): -2.193170348767403E+03
#    KEDF-TF energy (eV):  8.240122690090426E+03
#    KEDF-VW energy (eV):  2.106713103959099E+03
#     PSEUDO energy (eV): -2.058633215699334E+05
#         XC energy (eV): -7.925591610574601E+03
#      TOTAL energy (eV): -2.058777286192720E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            299.641680801583618
#   kedfs energy (eV)              :           8153.665445282123073
#   total energy (a.u.)            :           -756.586703944123656
#   total energy (eV)              :         -20587.772861927202030
#   total energy (eV/atom)         :            -57.347556718460176
# Calculate Force...
#               Max force (a.u.) : 0.06352
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.01116
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00042     -0.00000     -0.00000
#                     -0.00000      0.00016     -0.00000
#                     -0.00000     -0.00000     -0.02816
#         II stress (a.u.):
#                      0.00208     -0.00000     -0.00001
#                     -0.00000      0.00256     -0.00006
#                     -0.00001     -0.00006     -0.02795
#    KEDF-NL stress (a.u.):
#                      0.00048      0.00000     -0.00000
#                      0.00000      0.00042     -0.00000
#                     -0.00000     -0.00000      0.00033
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00045      0.00000      0.00000
#                      0.00000     -0.00042     -0.00000
#                      0.00000     -0.00000     -0.00031
#     PSEUDO stress (a.u.):
#                     -0.00112      0.00001      0.00001
#                      0.00001     -0.00215      0.00005
#                      0.00001      0.00005      0.05669
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00030      0.00000      0.00000
#                      0.00000     -0.00030     -0.00002
#                      0.00000     -0.00002     -0.00026
#      TOTAL stress (GPa):
#                     -8.77880      0.01055      0.03957
#                      0.01055     -8.89288     -0.53018
#                      0.03957     -0.53018     -7.61778
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.542730240456E+02     -7.542730E+02   7.476972E+00    1       1       2.297821E-01
# 1       -7.569699031750E+02     -2.696879E+00   1.187298E+00    6       1       8.094530E-01
# 2       -7.571451449594E+02     -1.752418E-01   1.651522E-01    8       2       1.640812E+00
# 3       -7.571802602542E+02     -3.511529E-02   2.608309E-02    11      2       2.696902E+00
# 4       -7.571858697063E+02     -5.609452E-03   5.187562E-03    12      2       3.841359E+00
# 5       -7.571866966840E+02     -8.269776E-04   7.728206E-04    9       2       4.744292E+00
# 6       -7.571869049897E+02     -2.083057E-04   2.091656E-04    12      2       5.915264E+00
# 7       -7.571869449985E+02     -4.000880E-05   3.448306E-05    8       2       6.742125E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02416307298598109
# Chemical potential (eV)  : -0.6575107065564915
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.008207429287212E+05
#         II energy (eV):  8.249519815089183E+04
#    KEDF-NL energy (eV): -2.326255750913450E+03
#    KEDF-TF energy (eV):  8.292885017967172E+03
#    KEDF-VW energy (eV):  2.181937405737151E+03
#     PSEUDO energy (eV): -2.041294169263447E+05
#         XC energy (eV): -7.939197079024366E+03
#      TOTAL energy (eV): -2.060410625296516E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            299.454304367076247
#   kedfs energy (eV)              :           8148.566672790873781
#   total energy (a.u.)            :           -757.186944998486979
#   total energy (eV)              :         -20604.106252965157182
#   total energy (eV/atom)         :            -57.393053629429410
# Calculate Force...
#               Max force (a.u.) : 0.06748
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.01045
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00043     -0.00000     -0.00000
#                     -0.00000      0.00015     -0.00001
#                     -0.00000     -0.00001     -0.02791
#         II stress (a.u.):
#                      0.00209     -0.00001     -0.00001
#                     -0.00001      0.00254     -0.00007
#                     -0.00001     -0.00007     -0.02769
#    KEDF-NL stress (a.u.):
#                      0.00050      0.00000     -0.00000
#                      0.00000      0.00044     -0.00001
#                     -0.00000     -0.00001      0.00035
#    KEDF-TF stress (a.u.):
#                     -0.00155      0.00000      0.00000
#                      0.00000     -0.00155      0.00000
#                      0.00000      0.00000     -0.00155
#    KEDF-VW stress (a.u.):
#                     -0.00047     -0.00000      0.00000
#                     -0.00000     -0.00043      0.00000
#                      0.00000      0.00000     -0.00032
#     PSEUDO stress (a.u.):
#                     -0.00113      0.00001      0.00001
#                      0.00001     -0.00215      0.00007
#                      0.00001      0.00007      0.05616
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00031     -0.00000      0.00000
#                     -0.00000     -0.00032     -0.00002
#                      0.00000     -0.00002     -0.00027
#      TOTAL stress (GPa):
#                     -9.09589     -0.00851      0.03778
#                     -0.00851     -9.38233     -0.55738
#                      0.03778     -0.55738     -8.08308
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.555182456520E+02     -7.555182E+02   6.336662E+00    1       1       2.295530E-01
# 1       -7.573195330380E+02     -1.801287E+00   1.225330E+00    6       1       8.050950E-01
# 2       -7.575254657110E+02     -2.059327E-01   1.175483E-01    8       2       1.629356E+00
# 3       -7.575537233402E+02     -2.825763E-02   1.871441E-02    10      2       2.639150E+00
# 4       -7.575580091018E+02     -4.285762E-03   3.827649E-03    13      2       3.865454E+00
# 5       -7.575587124964E+02     -7.033946E-04   5.982737E-04    9       2       4.769792E+00
# 6       -7.575588718433E+02     -1.593468E-04   1.542708E-04    13      2       5.989544E+00
# 7       -7.575589020326E+02     -3.018937E-05   2.885691E-05    9       2       6.890924E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02433264472067715
# Chemical potential (eV)  : -0.6621249884881276
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.968520715031850E+04
#         II energy (eV):  8.132842967284239E+04
#    KEDF-NL energy (eV): -2.353963564060112E+03
#    KEDF-TF energy (eV):  8.276946220027572E+03
#    KEDF-VW energy (eV):  2.193604954415631E+03
#     PSEUDO energy (eV): -2.018150601780794E+05
#         XC energy (eV): -7.929391974870890E+03
#      TOTAL energy (eV): -2.061422771940624E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            298.279095490205862
#   kedfs energy (eV)              :           8116.587610383090578
#   total energy (a.u.)            :           -757.558902032649712
#   total energy (eV)              :         -20614.227719406237156
#   total energy (eV/atom)         :            -57.421247129265282
# Calculate Force...
#               Max force (a.u.) : 0.04900
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00955
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00043     -0.00001     -0.00000
#                     -0.00001      0.00015     -0.00001
#                     -0.00000     -0.00001     -0.02759
#         II stress (a.u.):
#                      0.00210     -0.00001     -0.00001
#                     -0.00001      0.00253     -0.00006
#                     -0.00001     -0.00006     -0.02736
#    KEDF-NL stress (a.u.):
#                      0.00050     -0.00000     -0.00000
#                     -0.00000      0.00045     -0.00001
#                     -0.00000     -0.00001      0.00036
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00047     -0.00000      0.00000
#                     -0.00000     -0.00043      0.00000
#                      0.00000      0.00000     -0.00033
#     PSEUDO stress (a.u.):
#                     -0.00114      0.00001      0.00001
#                      0.00001     -0.00214      0.00006
#                      0.00001      0.00006      0.05551
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00030     -0.00000      0.00000
#                     -0.00000     -0.00031     -0.00002
#                      0.00000     -0.00002     -0.00028
#      TOTAL stress (GPa):
#                     -8.89553     -0.03995      0.00410
#                     -0.03995     -9.03426     -0.53484
#                      0.00410     -0.53484     -8.12027
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.568935533842E+02     -7.568936E+02   2.915999E+00    1       1       2.384989E-01
# 1       -7.577201897770E+02     -8.266364E-01   5.213701E-01    6       1       8.280900E-01
# 2       -7.578092345448E+02     -8.904477E-02   7.265005E-02    11      2       1.888175E+00
# 3       -7.578224382004E+02     -1.320366E-02   1.252978E-02    11      2       2.961811E+00
# 4       -7.578243410337E+02     -1.902833E-03   1.643136E-03    7       2       3.711269E+00
# 5       -7.578247354525E+02     -3.944187E-04   2.572938E-04    11      2       4.758939E+00
# 6       -7.578247840250E+02     -4.857253E-05   5.097337E-05    12      2       5.904708E+00
# 7       -7.578247930331E+02     -9.008090E-06   8.520208E-06    11      2       6.970211E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.02449290834992806
# Chemical potential (eV)  : -0.6664859839693401
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  9.895829698256879E+04
#         II energy (eV):  8.056555385001353E+04
#    KEDF-NL energy (eV): -2.429563979585214E+03
#    KEDF-TF energy (eV):  8.305566663012427E+03
#    KEDF-VW energy (eV):  2.235993829964724E+03
#     PSEUDO energy (eV): -2.003213459930003E+05
# ...
#                      0.04656     -9.79313     -0.12926
#                      0.01899     -0.12926     -9.25837
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.614930666009E+02     -7.614931E+02   3.135299E-01    1       1       2.282879E-01
# 1       -7.615867031571E+02     -9.363656E-02   1.975135E-02    6       1       7.759817E-01
# 2       -7.615920093189E+02     -5.306162E-03   1.950958E-03    10      1       1.632536E+00
# 3       -7.615922261996E+02     -2.168807E-04   2.385712E-04    8       2       2.418976E+00
# 4       -7.615922716519E+02     -4.545226E-05   3.391762E-05    12      2       3.514245E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.0271287021801501
# Chemical potential (eV)  : -0.7382095873641576
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  8.157557776991847E+04
#         II energy (eV):  6.278727926184207E+04
#    KEDF-NL energy (eV): -2.986858110452573E+03
#    KEDF-TF energy (eV):  8.287412855223734E+03
#    KEDF-VW energy (eV):  2.663841222486810E+03
#     PSEUDO energy (eV): -1.651596826241065E+05
#         XC energy (eV): -7.891551672005507E+03
#      TOTAL energy (eV): -2.072398129709349E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            292.686155719007331
#   kedfs energy (eV)              :           7964.395967257971279
#   total energy (a.u.)            :           -761.592271651858937
#   total energy (eV)              :         -20723.981297093494504
#   total energy (eV/atom)         :            -57.726967401374637
# Calculate Force...
#               Max force (a.u.) : 0.02314
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00210
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                      0.00066      0.00017     -0.00000
#                      0.00017     -0.00121     -0.00002
#                     -0.00000     -0.00002     -0.02226
#         II stress (a.u.):
#                      0.00321      0.00023     -0.00000
#                      0.00023      0.00106     -0.00005
#                     -0.00000     -0.00005     -0.02182
#    KEDF-NL stress (a.u.):
#                      0.00064      0.00001     -0.00000
#                      0.00001      0.00058     -0.00001
#                     -0.00000     -0.00001      0.00045
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00057     -0.00001      0.00000
#                     -0.00001     -0.00052      0.00000
#                      0.00000      0.00000     -0.00040
#     PSEUDO stress (a.u.):
#                     -0.00341     -0.00041      0.00001
#                     -0.00041      0.00063      0.00006
#                      0.00001      0.00006      0.04459
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00034      0.00000      0.00000
#                      0.00000     -0.00033     -0.00000
#                      0.00000     -0.00000     -0.00031
#      TOTAL stress (GPa):
#                    -10.02386      0.04491      0.02322
#                      0.04491     -9.78864     -0.13198
#                      0.02322     -0.13198     -9.26336
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.615611045896E+02     -7.615611E+02   1.056756E-01    1       1       2.268550E-01
# 1       -7.615904408011E+02     -2.933621E-02   9.769501E-03    5       1       6.958969E-01
# 2       -7.615933824526E+02     -2.941652E-03   3.908583E-04    10      1       1.548544E+00
# 3       -7.615934750589E+02     -9.260622E-05   4.305910E-05    9       1       2.334374E+00
# 4       -7.615934859344E+02     -1.087556E-05   7.666610E-06    12      2       3.426581E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.026899043800509583
# Chemical potential (eV)  : -0.7319602645420288
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  8.157703980357175E+04
#         II energy (eV):  6.278198951815470E+04
#    KEDF-NL energy (eV): -2.987107087342411E+03
#    KEDF-TF energy (eV):  8.287764587237971E+03
#    KEDF-VW energy (eV):  2.664057021026940E+03
#     PSEUDO energy (eV): -1.651560229479517E+05
#         XC energy (eV): -7.891735234102354E+03
#      TOTAL energy (eV): -2.072401433940506E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            292.697862350350704
#   kedfs energy (eV)              :           7964.714520922500014
#   total energy (a.u.)            :           -761.593485934422006
#   total energy (eV)              :         -20724.014339405061037
#   total energy (eV/atom)         :            -57.727059441239724
# Calculate Force...
#               Max force (a.u.) : 0.02312
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00210
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                      0.00067      0.00018     -0.00000
#                      0.00018     -0.00121     -0.00002
#                     -0.00000     -0.00002     -0.02226
#         II stress (a.u.):
#                      0.00322      0.00024     -0.00000
#                      0.00024      0.00105     -0.00005
#                     -0.00000     -0.00005     -0.02182
#    KEDF-NL stress (a.u.):
#                      0.00064      0.00001     -0.00000
#                      0.00001      0.00058     -0.00001
#                     -0.00000     -0.00001      0.00045
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00057     -0.00001      0.00000
#                     -0.00001     -0.00052      0.00000
#                      0.00000      0.00000     -0.00040
#     PSEUDO stress (a.u.):
#                     -0.00342     -0.00042      0.00001
#                     -0.00042      0.00064      0.00006
#                      0.00001      0.00006      0.04459
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00034      0.00000      0.00000
#                      0.00000     -0.00033     -0.00000
#                      0.00000     -0.00000     -0.00031
#      TOTAL stress (GPa):
#                    -10.02404      0.04388      0.02601
#                      0.04388     -9.78713     -0.13201
#                      0.02601     -0.13201     -9.26667
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.608560012992E+02     -7.608560E+02   2.381864E+00    1       1       2.490458E-01
# 1       -7.615521503920E+02     -6.961491E-01   1.686788E-01    6       1       8.027461E-01
# 2       -7.615918720942E+02     -3.972170E-02   9.410769E-03    10      1       1.660102E+00
# 3       -7.615932626311E+02     -1.390537E-03   1.078114E-03    8       1       2.378177E+00
# 4       -7.615934969011E+02     -2.342700E-04   1.671832E-04    12      2       3.492155E+00
# 5       -7.615935393165E+02     -4.241533E-05   4.595611E-05    13      2       4.664427E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.026851454890283944
# Chemical potential (eV)  : -0.7306653043354
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  8.163629165353571E+04
#         II energy (eV):  6.284050186062858E+04
#    KEDF-NL energy (eV): -2.987356968028116E+03
#    KEDF-TF energy (eV):  8.289362619735617E+03
#    KEDF-VW energy (eV):  2.664155616500921E+03
#     PSEUDO energy (eV): -1.652744529128815E+05
#         XC energy (eV): -7.892517661495346E+03
#      TOTAL energy (eV): -2.072401579200414E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            292.751029332900771
#   kedfs energy (eV)              :           7966.161268208420552
#   total energy (a.u.)            :           -761.593539316454098
#   total energy (eV)              :         -20724.015792004141986
#   total energy (eV/atom)         :            -57.727063487476720
# Calculate Force...
#               Max force (a.u.) : 0.02265
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00232
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                      0.00068      0.00020     -0.00000
#                      0.00020     -0.00123     -0.00002
#                     -0.00000     -0.00002     -0.02227
#         II stress (a.u.):
#                      0.00323      0.00026     -0.00000
#                      0.00026      0.00103     -0.00005
#                     -0.00000     -0.00005     -0.02183
#    KEDF-NL stress (a.u.):
#                      0.00064      0.00002      0.00000
#                      0.00002      0.00058     -0.00001
#                      0.00000     -0.00001      0.00045
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00057     -0.00001      0.00000
#                     -0.00001     -0.00052      0.00000
#                      0.00000      0.00000     -0.00040
#     PSEUDO stress (a.u.):
#                     -0.00344     -0.00047      0.00001
#                     -0.00047      0.00069      0.00007
#                      0.00001      0.00007      0.04460
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00034      0.00000      0.00000
#                      0.00000     -0.00033     -0.00000
#                      0.00000     -0.00000     -0.00032
#      TOTAL stress (GPa):
#                    -10.01627      0.04168      0.04183
#                      0.04168     -9.79046     -0.13246
#                      0.04183     -0.13246     -9.29133
# --------------------------------------------------------------------------------
# The final grid size is  [ 78  78 154]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.613657147601E+02     -7.613657E+02   7.598677E-01    1       1       2.222269E-01
# 1       -7.615831092317E+02     -2.173945E-01   5.440006E-02    6       1       7.879691E-01
# 2       -7.615955612896E+02     -1.245206E-02   5.195917E-03    10      1       1.648551E+00
# 3       -7.615961868632E+02     -6.255736E-04   8.199352E-04    8       2       2.437062E+00
# 4       -7.615963171584E+02     -1.302952E-04   1.015830E-04    10      2       3.375805E+00
# 5       -7.615963456561E+02     -2.849766E-05   2.081047E-05    11      2       4.400189E+00
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.027057712886350713
# Chemical potential (eV)  : -0.7362778702869852
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  8.160413318381550E+04
#         II energy (eV):  6.281378379140599E+04
#    KEDF-NL energy (eV): -2.987738536186017E+03
#    KEDF-TF energy (eV):  8.288796980909461E+03
#    KEDF-VW energy (eV):  2.664304342467859E+03
#     PSEUDO energy (eV): -1.652151905182099E+05
#         XC energy (eV): -7.892181400598261E+03
#      TOTAL energy (eV): -2.072409215639539E+04
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :            292.721685696512566
#   kedfs energy (eV)              :           7965.362787191303141
#   total energy (a.u.)            :           -761.596345656093490
#   total energy (eV)              :         -20724.092156395385246
#   total energy (eV/atom)         :            -57.727276201658455
# Calculate Force...
#               Max force (a.u.) : 0.02283
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00206
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                      0.00067      0.00019     -0.00000
#                      0.00019     -0.00122     -0.00002
#                     -0.00000     -0.00002     -0.02226
#         II stress (a.u.):
#                      0.00322      0.00025     -0.00000
#                      0.00025      0.00104     -0.00005
#                     -0.00000     -0.00005     -0.02182
#    KEDF-NL stress (a.u.):
#                      0.00064      0.00002     -0.00000
#                      0.00002      0.00058     -0.00001
#                     -0.00000     -0.00001      0.00045
#    KEDF-TF stress (a.u.):
#                     -0.00154      0.00000      0.00000
#                      0.00000     -0.00154      0.00000
#                      0.00000      0.00000     -0.00154
#    KEDF-VW stress (a.u.):
#                     -0.00057     -0.00001      0.00000
#                     -0.00001     -0.00052      0.00000
#                      0.00000      0.00000     -0.00040
#     PSEUDO stress (a.u.):
#                     -0.00343     -0.00044      0.00001
#                     -0.00044      0.00066      0.00007
#                      0.00001      0.00007      0.04460
#         XC stress (a.u.):
#                      0.00067      0.00000      0.00000
#                      0.00000      0.00067      0.00000
#                      0.00000      0.00000      0.00067
#      TOTAL stress (a.u.):
#                     -0.00034      0.00000      0.00000
#                      0.00000     -0.00033     -0.00000
#                      0.00000     -0.00000     -0.00032
#      TOTAL stress (GPa):
#                    -10.02543      0.04475      0.03424
#                      0.04475     -9.78779     -0.13089
#                      0.03424     -0.13089     -9.28056
# --------------------------------------------------------------------------------
# [relax_atoms] after  run fixed_z(min/max)=0.000000/39.750566
# Saved: /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/cycle_000_relaxed.xyz exists: True
# Saved: /Users/dawson666/Desktop/nano_tensile_TFvW/cases/case_center/ref_energy.json exists: True
# E_ref_eV = -20724.092156395385

# %%
ref_xyz = WORKDIR / "cycle_000_relaxed.xyz"
assert ref_xyz.exists(), "Reference relaxed structure not written"

ref_json = WORKDIR / "ref_energy.json"
assert ref_json.exists(), "Reference energy json not written"

print("Reference relax OK")
# Out:
# Reference relax OK
